# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Dataframe').getOrCreate()
# Out:
# c:\Users\Asus\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pyspark\testing\utils.py:127: FutureWarning: PySpark does not yet fully support pandas >= 3.0.0. Some features may not work correctly. It is recommended to use pandas < 3.0.0 for now.
#   require_minimum_pandas_version()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-TG6KMDAH:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
##read the dataset
df_pyspark=spark.read.option('header','true').csv('spark_data.csv',inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +------+---+----------+
# |  name|age|experience|
# +------+---+----------+
# |sarang| 23|        10|
# |   him| 30|         8|
# | sunny| 35|         4|
# +------+---+----------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- experience: integer (nullable = true)

# %%
df_pyspark=spark.read.csv('spark_data.csv',header=True,inferSchema=True)
df_pyspark.show()
# Out:
# +------+---+----------+
# |  name|age|experience|
# +------+---+----------+
# |sarang| 23|        10|
# |   him| 30|         8|
# | sunny| 35|         4|
# +------+---+----------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- experience: integer (nullable = true)

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.head(2)
# Out:
# [Row(name='sarang', age=23, experience=10),
#  Row(name='him', age=30, experience=8)]

# %%
df_pyspark.select
